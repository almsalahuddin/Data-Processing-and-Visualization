# %% [markdown]
# <a href="https://colab.research.google.com/github/almsalahuddin/Data-Processing-and-Visualization/blob/main/Exam_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EXAM 3 : CPSMA 4313 [Dr. Jacob's](https://github.com/nurfnick) Data processing visualization
#
# ### A L M SALAHUDDIN

# %% [markdown]
# ##(a) (10 points) Store the data as a pandas dataframe. Find your favorite ‘club’ or ‘nationality’ (that is present in the data!), include a picture that represents them and include it in your notebook.

# %% [markdown]
# #Import Libraries and Make Requests

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/worldCupPlayer.csv')
df.head()
# Out:
#    Unnamed: 0  Rank               player           club  age   Apps  Mins  \
# 0           0     1         Hakim Ziyech           Ajax   25     34  3043
# 1           2     2  Alireza Jahanbakhsh     AZ Alkmaar   24     33  2840
# 2           4     3       Hirving Lozano  PSV Eindhoven   22     29  2350
# 3           6    11         Lasse Schone           Ajax   32  27(3)  2350
# 4          10    25       Santiago Arias  PSV Eindhoven   26     30  2664
#
#    Goals  Assists  Yel  Red  SpG    PS AerialsWon  MotM  Rating nationality
# 0      9       15    4    0  4.9  75.4        0.2     9    8.21     Morocco
# 1     21       12    3    0  4.3  73.4        0.7    14    8.20        Iran
# 2     17        8    4    2  3.4  75.3        0.6     8    7.90      Mexico
# 3     10        3    6    0  1.9  87.0        1.9     2    7.45     Denmark
# 4      3        6    5    0  1.5  82.3          1     2    7.25    Colombia

# %% [markdown]
# My favourite team from world cup is Brazil.
#
# #[Brazil](https://www.aa.com.tr/en/world-cup-2018/fifa-world-cup-2018-group-e-brazil-/1172523)
#
# ##FIFA World Cup 2018 Group
#
#
#
# ![](https://cdnuploads.aa.com.tr/uploads/Contents/2018/06/12/thumbs_b_c_7153ea72576d5567683555cf78be57a8.jpg?v=120257)

# %% [markdown]
# Let's find out if there is my favourite country name Brazil in the dataset or not.

# %%
df[df['nationality']=='Brazil']
# Out:
#      Unnamed: 0  Rank           player                 club  age    Apps  \
# 69          133   110          Marcelo                 Lyon   31      10
# 70          135    44          Marcelo          Real Madrid   30   26(2)
# 71          137    25          Marcelo                 Lyon   31      35
# 72          139    69          Marcelo              Rio Ave   28      30
# 73          141    46          Marcelo          Real Madrid   30      11
# 84          163   138           Danilo                Braga   22       6
# 85          165    91           Danilo      Manchester City   26  13(10)
# 86          167    55           Danilo                Braga   22  15(16)
# 87          169   227           Danilo      Manchester City   26    4(2)
# 88          171   165           Danilo              Udinese   34      32
# 168         329   534         Paulinho                Braga   25    6(1)
# 169         331    99         Paulinho            Barcelona   29  21(13)
# ...

# %% [markdown]
# ##(b) (10 points) Show a table with all the data about your favorite club or nationality. Include some description about an interesting fact in the data.

# %%
fav_nationality=df[df['nationality']=='Brazil']
fav_nationality.head()
# Out:
#     Unnamed: 0  Rank   player         club  age   Apps  Mins  Goals  Assists  \
# 69         133   110  Marcelo         Lyon   31     10   900      1        0
# 70         135    44  Marcelo  Real Madrid   30  26(2)  2262      2        6
# 71         137    25  Marcelo         Lyon   31     35  3107      3        1
# 72         139    69  Marcelo      Rio Ave   28     30  2621      0        0
# 73         141    46  Marcelo  Real Madrid   30     11   958      3        4
#
#     Yel  Red  SpG    PS AerialsWon  MotM  Rating nationality
# 69    2    0  0.2  85.0        3.9     0    7.19      Brazil
# 70    3    1  1.2  84.6        0.3     1    7.07      Brazil
# 71    5    1  0.6  87.6          4     1    7.18      Brazil
# 72   10    1  0.3  82.3          2     1    6.88      Brazil
# 73    1    0  0.9  82.5        0.5     0    7.29      Brazil

# %% [markdown]
# Interesting fact about the table above is Neymar has rank 1 in the table and has scored most number of goals and assists among all Brazilian players.

# %% [markdown]
# ##(c) (10 points) Create a histogram of the ‘Goals’.

# %%
df.Goals.plot.hist()

# %%
ax = df.Goals.hist(bins = 25)
ax.set(title = "Histogram of Goals")
plt.show()

# %% [markdown]
# ##(d) (10 points) Create a histogram of the ‘Goals’ and ‘Assists’ on the same axis.

# %%
plt.hist(df['Goals'], alpha=0.5, label='Goals')
plt.hist(df['Assists'], alpha=0.5, label='Assists')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ##(e) (10 points) Create a barchart for most goals scored by nationality.

# %%
df.groupby('nationality').Goals.agg('max').plot(kind = 'bar')

# %% [markdown]
# As we can see above, Argentina scored (34) most goals in the 2018 world cup.

# %% [markdown]
# ##(f) (10 points) Create a boxplot of ‘Yel’ (yellow cards) by nationality.

# %%
sns.boxplot(data = df, x = 'Yel', y = 'nationality')

# %% [markdown]
# ##(g) (10 points) Create ‘Goals’ and ‘Assists’ as scatter. Signify your favorite club or nationality in some way on the scatterplot. You may need to add a new column to the dataset to do so.

# %%
ax = sns.scatterplot(data = df, x = 'Goals', y = 'Assists')
ax.set(title = "Goals and Assists",
       xticks = [x for x in range(4,9,1)])
plt.show()

# %%
ax = sns.scatterplot(data = df, 
                x = 'Goals', 
                y = 'Assists',
                style = 'Goals', 
                size = 'Assists',
                palette='deep',
                legend='full',
                color='.2', 
                marker='+' )

# %% [markdown]
# Above both are the scatter plot of the whole data set.

# %% [markdown]
# Next, I will create ‘Goals’ and ‘Assists’ as scatter using only data for my favourite nationality "Brazil".

# %%
ax = sns.scatterplot(data = fav_nationality, 
                x = 'Goals', 
                y = 'Assists',
                style = 'Goals', 
                size = 'Assists',
                palette='deep',
                legend='full',
                color='.2', 
                marker='+' )

# %% [markdown]
# ##(h) (10 points) Create stacked barplot of goals and assists of French National Team. (they won this tourney!) Be sure to comment on why it is appropriate to stack goals and assists.

# %% [markdown]
# Let's gather all the data for only Franch nationality.

# %%
fra_nationality=df[df['nationality']=='France']
fra_nationality.head()
# Out:
#     Unnamed: 0  Rank             player             club  age   Apps  Mins  \
# 30          59     5  Antoine Griezmann  Atletico Madrid   27   7(1)   631
# 31          60    13  Antoine Griezmann  Atletico Madrid   27  30(2)  2530
# 32          62   140  Antoine Griezmann  Atletico Madrid   27      6   529
# 33          64     8        Nabil Fekir             Lyon   24      8   660
# 34          65     3        Nabil Fekir             Lyon   24  28(2)  2481
#
#     Goals  Assists  Yel  Red  SpG    PS AerialsWon  MotM  Rating nationality
# 30      6        2    0    0  3.6  78.8        0.5     3    7.91      France
# 31     19        9    7    1  2.3  77.6        0.8     8    7.38      France
# 32      2        2    1    0    3  84.1        0.5     1    6.98      France
# 33      3        1    2    0  2.5  85.9        0.3     3    7.73      France
# 34     18        8    8    0    3  85.3        0.7    12    7.86      France

# %% [markdown]
# Now, I will create stacked barplot of goals and assists of French National Team using above dataset.

# %%
fra_nationality[['Goals', 'Assists']].plot(kind = 'bar', stacked = True)

# %% [markdown]
# It is appropriete to stack goals and assists in a stacked bar graph because these two are related to each other. If any player scored a goal there should be some one assist to scored that goal. Assist only counts against a goal. So, it perfectly stacked with each other.

# %% [markdown]
# ##(i) (10 points) Create a correlation heatmap of the entire dataset.

# %%
ax = sns.heatmap(df.corr(),vmin = -1)
ax.set(title = 'Heatmap of 2018 world Cup players')

plt.show()

# %% [markdown]
# ##Question: Approximately how long did you work on this exam?
#
# Answer: I worked around 3 hours on this.

# %% [markdown]
# ##Question:Which was the hardest and easiest topic from this section?
#
# Answer: Question number (g) was the hardest and question (c) creating histogram was easiest.

# %% [markdown]
# ##Question: Which method of visualization are you still unclear what it might show?
#
# Answer: We have covered most of the important data visualiztion method in the class and got clear ideas about all. I would like to know details about Area Graph because I have seen this graph in multiple places speacially in stock market and would like to know more about this.

# %% [markdown]
# #References
#
# (c)https://github.com/nurfnick/Data_Viz/blob/main/25_Histograms.ipynb
#
# (c),(f),(i)https://github.com/nurfnick/Data_Viz/blob/main/30_Visualize_Conclusion.ipynb
#
# (e)https://github.com/nurfnick/Data_Viz/blob/main/24_Amounts.ipynb
#
# (a)(b) https://www.edureka.co/community/43207/how-to-find-an-element-in-pandas-dataframe
#
# (d)https://stackoverflow.com/questions/6871201/plot-two-histograms-on-single-chart-with-matplotlib
#
# (h)https://www.youtube.com/watch?v=oiITOShYIkA

# %% [markdown]
# “I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.”
